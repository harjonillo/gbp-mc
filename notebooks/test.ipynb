# %%
import sys

# # caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '../')

from src.core import analyze 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 # # caution: path[0] is reserved for script path (or '' in REPL)
#       4 sys.path.insert(1, '../')
# ----> 6 from src.core import analyze
#       7 import numpy as np
#       8 import matplotlib.pyplot as plt
#
# File ~/Documents/gbp-mc/notebooks/../src/core/analyze.py:13
#      11 import numpy as np
#      12 import matplotlib.pyplot as pl
# ---> 13 import gaussian_beam_propagation as gbp
#      14 import intersect
#      15 import zipfile
#
# ModuleNotFoundError: No module named 'gaussian_beam_propagation'

# %%
arr = np.load('../data/iplt1_arjonillo-8/gbpc1N1E05NA02sp1E-18t0.npz')

# %%
list(arr.keys())
# Out:
# ['vars', 'intensity_distribution', 'transverse_edges', 'axial_edges', 'paths']

# %%
corr_arr = np.load("../data/iplt1_arjonillo-8/gbpc1N1E05NA02_correlation-info.npz")

# %%
list(corr_arr.keys())
# Out:
# ['arr_0', 'arr_1']

# %%
plt.plot(corr_arr['arr_0'], corr_arr['arr_1'])
